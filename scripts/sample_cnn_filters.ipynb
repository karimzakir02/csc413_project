# %%
import numpy as np
import pandas as pd
import h5py

# %% [markdown]
# Please download the .h5 dataset and decompress:
# [https://zenodo.org/records/6371680](https://zenodo.org/records/6371680)
# ```bash
# xz -dv /path/to/dataset.tar.xz
# ```
#
# You may also need to install h5py
# ```bash
# sudo apt update -y && sudo apt install python3-h5py
# ```

# %% [markdown]
# ## Load data

# %%
dataset_path = "/workspace/dataset.h5" #"path/to/dataset.h5"

# %%
df_meta = pd.read_hdf(dataset_path, "meta")

# %%
df_meta_classif = df_meta[df_meta["Task"] == "Classification"] # Only want classification models
df_meta_classif = df_meta_classif.copy() # Make not a slice
del df_meta # Remove from mem

# %%
num_model_samples = 500
# Pick random models from dataset
rand_models_ind = np.random.choice(len(df_meta_classif), num_model_samples, replace=False)
df_meta_sample = df_meta_classif.copy().iloc[rand_models_ind]
del df_meta_classif # remove from mem

# %%
df_meta_sample["filter_ids"] = df_meta_sample["filter_ids"].apply(lambda s: list(np.arange(int(s.split(":")[0]), 1 + int(s.split(":")[1]))))
df_meta_sample
# Out:
#                                      layer_depth  \
# model_id conv_depth conv_depth_norm
# 294      20         0.833333                  58
# 57       104        0.654088                 317
# 403      35         0.777778                  54
# 91       5          0.312500                  13
# 36       50         0.420168                 155
# ...                                          ...
# 59       137        0.861635                 418
# 631      95         0.633333                 222
# 234      8          0.333333                  24
# 482      65         0.541667                 195
# 437      2          1.000000                 426
#
#                                                                             filter_ids  \
# model_id conv_depth conv_depth_norm
# 294      20         0.833333         [998059162, 998059163, 998059164, 998059165, 9...
# 57       104        0.654088         [40282954, 40282955, 40282956, 40282957, 40282...
# 403      35         0.777778         [1143012822, 1143012823, 1143012824, 114301282...
# 91       5          0.312500         [73806698, 73806699, 73806700, 73806701, 73806...
# 36       50         0.420168         [29335914, 29335915, 29335916, 29335917, 29335...
# ...                                                                                ...
# 59       137        0.861635         [41485290, 41485291, 41485292, 41485293, 41485...
# 631      95         0.633333         [1409699152, 1409699153, 1409699154, 140969915...
# 234      8          0.333333         [423170186, 423170187, 423170188, 423170189, 4...
# 482      65         0.541667         [1268530726, 1268530727, 1268530728, 126853072...
# 437      2          1.000000         [1203876008, 1203876009, 1203876010, 120387601...
#
#                                                                                  model  \
# model_id conv_depth conv_depth_norm
# 294      20         0.833333         robustbench_wu2020adversarial_extra_linf_cifar...
# 57       104        0.654088                    hso_lowres_densenet161_fashionmnist_11
# 403      35         0.777778                          timm_hrnet_w18_small_imagenet_11
# 91       5          0.312500                       hso_lowres_resnet18_fashionmnist_11
# 36       50         0.420168                         hso_lowres_densenet121_cifar10_11
# ...                                                                                ...
# 59       137        0.861635                          hso_lowres_densenet161_kmnist_11
# 631      95         0.633333                                     resnet152_imagenet_11
# 234      8          0.333333            robustbench_hendrycks2019using_linf_cifar10_11
# 482      65         0.541667                         timm_res2net50_26w_8s_imagenet_11
# 437      2          1.000000                                timm_pit_b_224_imagenet_11
#
#                                                                                   path  \
# model_id conv_depth conv_depth_norm
# 294      20         0.833333         /data/onnx_zoo/robustbench/robustbench_wu2020a...
# 57       104        0.654088         /data/onnx_zoo/hso/hso_lowres_densenet161_fash...
# 403      35         0.777778         /data/onnx_zoo/timm_2/timm_hrnet_w18_small_ima...
# 91       5          0.312500         /data/onnx_zoo/hso/hso_lowres_resnet18_fashion...
# 36       50         0.420168         /data/onnx_zoo/hso/hso_lowres_densenet121_cifa...
# ...                                                                                ...
# 59       137        0.861635         /data/onnx_zoo/hso/hso_lowres_densenet161_kmni...
# 631      95         0.633333         /data/onnx_zoo/torchvision_official/resnet152_...
# 234      8          0.333333         /data/onnx_zoo/robustbench/robustbench_hendryc...
# 482      65         0.541667         /data/onnx_zoo/timm_2/timm_res2net50_26w_8s_im...
# 437      2          1.000000         /data/onnx_zoo/timm_2/timm_pit_b_224_imagenet_...
#
#                                          producer  op_set  Transpose   Conv  \
# model_id conv_depth conv_depth_norm
# 294      20         0.833333          pytorch 1.9      11        NaN   28.0
# 57       104        0.654088          pytorch 1.9      11        NaN  160.0
# 403      35         0.777778         pytorch 1.10      11        NaN   91.0
# 91       5          0.312500          pytorch 1.9      11        NaN   20.0
# 36       50         0.420168          pytorch 1.9      11        NaN  120.0
# ...                                           ...     ...        ...    ...
# 59       137        0.861635          pytorch 1.9      11        NaN  160.0
# 631      95         0.633333          pytorch 1.7      11        NaN  155.0
# 234      8          0.333333          pytorch 1.9      11        NaN   28.0
# 482      65         0.541667         pytorch 1.10      11        NaN  149.0
# 437      2          1.000000         pytorch 1.10      11       44.0    3.0
#
#                                      (3, 3) filters  Clip  ...  \
# model_id conv_depth conv_depth_norm                        ...
# 294      20         0.833333              4021808.0   NaN  ...
# 57       104        0.654088               718944.0   NaN  ...
# 403      35         0.777778               934592.0   NaN  ...
# 91       5          0.312500              1220672.0   NaN  ...
# 36       50         0.420168               237760.0   NaN  ...
# ...                                             ...   ...  ...
# 59       137        0.861635               718944.0   NaN  ...
# 631      95         0.633333              3289088.0   NaN  ...
# 234      8          0.333333              4021808.0   NaN  ...
# 482      65         0.541667              1452724.0   NaN  ...
# 437      2          1.000000                 1536.0   NaN  ...
#
#                                                                             Accessible  \
# model_id conv_depth conv_depth_norm
# 294      20         0.833333                https://github.com/RobustBench/robustbench
# 57       104        0.654088         https://github.com/paulgavrikov/pytorch-pretra...
# 403      35         0.777778         https://rwightman.github.io/pytorch-image-models/
# 91       5          0.312500         https://github.com/paulgavrikov/pytorch-pretra...
# 36       50         0.420168         https://github.com/paulgavrikov/pytorch-pretra...
# ...                                                                                ...
# 59       137        0.861635         https://github.com/paulgavrikov/pytorch-pretra...
# 631      95         0.633333         https://pytorch.org/docs/stable/model_zoo.html...
# 234      8          0.333333                https://github.com/RobustBench/robustbench
# 482      65         0.541667         https://rwightman.github.io/pytorch-image-models/
# 437      2          1.000000         https://rwightman.github.io/pytorch-image-models/
#
#                                      Dataset URL  Unnamed: 20  Unnamed: 21  \
# model_id conv_depth conv_depth_norm
# 294      20         0.833333                 NaN          NaN          NaN
# 57       104        0.654088                 NaN          NaN          NaN
# 403      35         0.777778                 NaN          NaN          NaN
# 91       5          0.312500                 NaN          NaN          NaN
# 36       50         0.420168                 NaN          NaN          NaN
# ...                                          ...          ...          ...
# 59       137        0.861635                 NaN          NaN          NaN
# 631      95         0.633333                 NaN          NaN          NaN
# 234      8          0.333333                 NaN          NaN          NaN
# 482      65         0.541667                 NaN          NaN          NaN
# 437      2          1.000000                 NaN          NaN          NaN
#
#                                      Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# model_id conv_depth conv_depth_norm
# 294      20         0.833333                 NaN          NaN          NaN
# 57       104        0.654088                 NaN          NaN          NaN
# 403      35         0.777778                 NaN          NaN          NaN
# 91       5          0.312500                 NaN          NaN          NaN
# 36       50         0.420168                 NaN          NaN          NaN
# ...                                          ...          ...          ...
# 59       137        0.861635                 NaN          NaN          NaN
# 631      95         0.633333                 NaN          NaN          NaN
# 234      8          0.333333                 NaN          NaN          NaN
# 482      65         0.541667                 NaN          NaN          NaN
# 437      2          1.000000                 NaN          NaN          NaN
#
#                                      Unnamed: 25  total_filters  \
# model_id conv_depth conv_depth_norm
# 294      20         0.833333                 NaN      4021808.0
# 57       104        0.654088                 NaN       718944.0
# 403      35         0.777778                 NaN       934592.0
# 91       5          0.312500                 NaN      1220672.0
# 36       50         0.420168                 NaN       237760.0
# ...                                          ...            ...
# 59       137        0.861635                 NaN       718944.0
# 631      95         0.633333                 NaN      3289280.0
# 234      8          0.333333                 NaN      4021808.0
# 482      65         0.541667                 NaN      1452916.0
# 437      2          1.000000                 NaN         2304.0
#
#                                      3x3_filter_share
# model_id conv_depth conv_depth_norm
# 294      20         0.833333                 1.000000
# 57       104        0.654088                 1.000000
# 403      35         0.777778                 1.000000
# 91       5          0.312500                 1.000000
# 36       50         0.420168                 1.000000
# ...                                               ...
# 59       137        0.861635                 1.000000
# 631      95         0.633333                 0.999942
# 234      8          0.333333                 1.000000
# 482      65         0.541667                 0.999868
# 437      2          1.000000                 0.666667
#
# [500 rows x 128 columns]

# %%
# Get dX_inds from df_meta_classif
dX_inds = np.concatenate([f for f in df_meta_sample["filter_ids"]])
dX_inds
# Out:
# array([ 998059162,  998059163,  998059164, ..., 1203877029, 1203877030,
#        1203877031])

# %%
# Sort sample ind (MUST for h5)
dX_inds.sort()

# %%
with h5py.File(dataset_path, "r") as f:
    dX = f["filters"][dX_inds].reshape(-1, 9).astype(np.float16)

# %%
np.save('sampled_cnn_models.npy', dX)
